# %% [markdown]
# # FPL Historical Data Ingestion
# This notebook focuses on fetching historical FPL data from https://github.com/vaastav/Fantasy-Premier-League/ and storing it in CSV format for efficient processing in subsequent notebooks.

# %% [markdown]
# ## 1. Install Required Libraries
# We need the `requests` library to interact with the FPL API, `pandas` for data manipulation, and `pyarrow` for Parquet file handling.

# %%
import requests
import os
from datetime import datetime

# %% [markdown]
# ## 2. Download FPL data
# The `download_fpl_data` function sends a GET request to download data from the github repo.

# %%
def download_fpl_data(start_year, end_year):
    """
    Downloads FPL data for each season from the specified URL.

    Args:
        start_year (int): The starting year of the season (e.g., 2016).
        end_year (int): The ending year of the season (e.g., 2025).
    """

    base_url = "https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/{season_year}/gws/merged_gw.csv"
    data_source = "fpl_historical"
    current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")
    data_dir = f"../data/raw/{data_source}/{current_datetime}"

    # Create the data directory if it doesn't exist
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)

    for year in range(start_year, end_year):
        season_year = f"{year}-{str(year + 1)[-2:]}"
        url = base_url.format(season_year=season_year)
        filename = f"{season_year.replace('-','_')}_merged_gw.csv"
        filepath = os.path.join(data_dir, filename)

        try:
            print(f"Downloading data for {season_year}...")
            response = requests.get(url)
            response.raise_for_status()  # Raise an exception for bad status codes

            with open(filepath, "w") as f:
                f.write(response.text)
            print(f"Data for {season_year} downloaded successfully to {filepath}")

        except requests.exceptions.RequestException as e:
            print(f"Error downloading data for {season_year}: {e}")

download_fpl_data(2016, 2025)
# Out:
# Downloading data for 2016-17...
# Data for 2016-17 downloaded successfully to ../data/raw/fpl_historical/20250313_225438/2016_17_merged_gw.csv
# Downloading data for 2017-18...
# Data for 2017-18 downloaded successfully to ../data/raw/fpl_historical/20250313_225438/2017_18_merged_gw.csv
# Downloading data for 2018-19...
# Data for 2018-19 downloaded successfully to ../data/raw/fpl_historical/20250313_225438/2018_19_merged_gw.csv
# Downloading data for 2019-20...
# Data for 2019-20 downloaded successfully to ../data/raw/fpl_historical/20250313_225438/2019_20_merged_gw.csv
# Downloading data for 2020-21...
# Data for 2020-21 downloaded successfully to ../data/raw/fpl_historical/20250313_225438/2020_21_merged_gw.csv
# Downloading data for 2021-22...
# Data for 2021-22 downloaded successfully to ../data/raw/fpl_historical/20250313_225438/2021_22_merged_gw.csv
# Downloading data for 2022-23...
# Data for 2022-23 downloaded successfully to ../data/raw/fpl_historical/20250313_225438/2022_23_merged_gw.csv
# Downloading data for 2023-24...
# Data for 2023-24 downloaded successfully to ../data/raw/fpl_historical/20250313_225438/2023_24_merged_gw.csv
# Downloading data for 2024-25...
# Data for 2024-25 downloaded successfully to ../data/raw/fpl_historical/20250313_225438/2024_25_merged_gw.csv
